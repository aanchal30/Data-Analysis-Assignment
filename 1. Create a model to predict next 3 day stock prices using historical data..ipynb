# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

data = pd.read_csv("data.csv")
data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-01-03  177.830002  182.880005  177.710007  182.009995  179.724548
# 1    2022-01-04  182.630005  182.940002  179.119995  179.699997  177.443558
# 2    2022-01-05  179.610001  180.169998  174.639999  174.919998  172.723572
# 3    2022-01-06  172.699997  175.300003  171.639999  172.000000  169.840256
# 4    2022-01-07  172.889999  174.139999  171.029999  172.169998  170.008102
# ..          ...         ...         ...         ...         ...         ...
# 246  2022-12-23  130.919998  132.419998  129.639999  131.860001  130.959961
# 247  2022-12-27  131.380005  131.410004  128.720001  130.029999  129.142441
# 248  2022-12-28  129.669998  131.029999  125.870003  126.040001  125.179688
# 249  2022-12-29  127.989998  130.479996  127.730003  129.610001  128.725311
# 250  2022-12-30  128.410004  129.949997  127.430000  129.929993  129.043121
#
#         Volume
# 0    104487900
# 1     99310400
# 2     94537600
# 3     96904000
# 4     86709100
# ..         ...
# 246   63814900
# 247   69007800
# 248   85438400
# 249   75703700
# 250   77034200
#
# [251 rows x 7 columns]

# %%
features = data[["Open", "High", "Low", "Close", "Volume"]]
target = data[["High"]]

# %%
target
# Out:
#            High
# 0    182.880005
# 1    182.940002
# 2    180.169998
# 3    175.300003
# 4    174.139999
# ..          ...
# 246  132.419998
# 247  131.410004
# 248  131.029999
# 249  130.479996
# 250  129.949997
#
# [251 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2)
model = LinearRegression()
model.fit(X_train, y_train)
next_3_days = model.predict(X_test.tail(3))

# %%
print(next_3_days)
# Out:
# [[145.57000733]
#  [165.55000305]
#  [150.27999878]]
